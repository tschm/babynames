# %%
import pandas as pd
# %matplotlib inline  
pd.options.display.max_rows=20

# %%
names = pd.read_csv("us.csv", index_col=["year","Name","Gender"])["n"]
names
# Out:
# /opt/conda/envs/beakerx/lib/python3.6/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# year  Name       Gender
# 1880  Mary       F         7065
#       Anna       F         2604
#       Emma       F         2003
#       Elizabeth  F         1939
#       Minnie     F         1746
#       Margaret   F         1578
#       Ida        F         1472
#       Alice      F         1414
#       Bertha     F         1320
#       Sarah      F         1288
#                            ...
# 2015  Ziyu       M            5
#       Zoel       M            5
#       Zohar      M            5
#       Zolton     M            5
#       Zyah       M            5
#       Zykell     M            5
#       Zyking     M            5
#       Zykir      M            5
#       Zyrus      M            5
#       Zyus       M            5
# Name: n, Length: 1858689, dtype: int64

# %%
f = names.loc[:,"Elvis","M"]
f.plot()
f.sort_values()
# Out:
# year
# 1887      5
# 1889      5
# 1895      5
# 1886      7
# 1892      7
# 1893      7
# 1901      7
# 1881      8
# 1908      8
# 1904      8
#        ...
# 1977    299
# 2002    314
# 2008    325
# 2000    333
# 2007    355
# 1999    361
# 1978    364
# 1958    373
# 1956    420
# 1957    598
# Name: n, Length: 125, dtype: int64

# %%
f = names.loc[:,"Elvis","F"]
f.plot()
f.sort_values()
# Out:
# year
# 1913     5
# 1982     5
# 1981     5
# 1978     5
# 1958     5
# 1948     5
# 1929     5
# 1942     5
# 1922     5
# 1919     5
#         ..
# 1920     6
# 1983     6
# 2007     6
# 1923     8
# 1918     8
# 1915     8
# 1924     9
# 1926    10
# 1935    10
# 1957    13
# Name: n, Length: 23, dtype: int64

# %%
f = names.loc[:,"Nikita","F"]
f.plot()
f.sort_values()
# Out:
# year
# 1949       5
# 1953       5
# 1956       5
# 1957      13
# 1958      16
# 1966      20
# 1968      21
# 1965      24
# 1967      25
# 1963      26
#         ...
# 1999     320
# 1990     337
# 1992     343
# 1998     359
# 1991     372
# 1997     398
# 1989     417
# 1988     453
# 1987     659
# 1986    1034
# Name: n, Length: 62, dtype: int64

# %%
a=names.groupby(["Name","Gender"]).sum()
a.sort_values()
# Out:
# Name          Gender
# Zzyzx         M               5
# Othan         M               5
# Joceleen      F               5
# Othal         F               5
# Charlain      F               5
# Charlae       F               5
# Jocelle       F               5
# Otello        M               5
# Charlay       F               5
# Jocelynmarie  F               5
#                          ...
# Charles       M         2371621
# Richard       M         2558165
# Joseph        M         2581785
# David         M         3589754
# William       M         4071645
# Mary          F         4118058
# Michael       M         4323928
# Robert        M         4803068
# John          M         5095674
# James         M         5120990
# Name: n, Length: 105386, dtype: int64
