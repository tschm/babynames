# %%
import pandas as pd
# %matplotlib inline  
pd.options.display.max_rows=20

# %%
boys = pd.read_csv("boys.csv", index_col=0)
girls = pd.read_csv("girls.csv", index_col=0)

# %%
boys
# Out:
#       Daniel  Peter  Hans  Thomas  Christian  Martin  Andreas  Michael  \
# 1910     NaN    NaN   NaN     NaN        NaN     NaN      NaN      NaN
# 1911     NaN    NaN   NaN     NaN        NaN     NaN      NaN      NaN
# 1912     NaN    NaN   NaN     NaN        NaN     NaN      NaN      NaN
# 1913     NaN    NaN   NaN     NaN        NaN     NaN      NaN      NaN
# 1914     NaN    NaN   3.0     NaN        NaN     NaN      NaN      NaN
# 1915     NaN    NaN   NaN     NaN        NaN     NaN      NaN      NaN
# 1916     NaN    NaN  13.0     NaN        NaN     NaN      NaN      NaN
# 1917     NaN    NaN  14.0     NaN        NaN     NaN      NaN      NaN
# 1918     NaN    NaN  17.0     NaN        5.0     NaN      NaN      NaN
# 1919     NaN    6.0  45.0     NaN        NaN     NaN      3.0      NaN
# ...      ...    ...   ...     ...        ...     ...      ...      ...
# 2006   173.0   23.0   NaN   172.0       97.0    69.0     44.0    134.0
# 2007   204.0   22.0   4.0   166.0       87.0    78.0     46.0    145.0
# 2008   194.0   11.0   7.0   165.0       89.0    67.0     43.0    116.0
# 2009   187.0   19.0   4.0   130.0       68.0    68.0     43.0     91.0
# 2010   170.0   24.0   5.0   143.0       69.0    72.0     39.0     97.0
# 2011   167.0   12.0   4.0   146.0       57.0    62.0     22.0     94.0
# 2012   165.0   15.0   6.0   160.0       67.0    72.0     25.0     65.0
# 2013   152.0   11.0   NaN   146.0       78.0    76.0     31.0     62.0
# 2014   168.0   20.0   5.0   129.0       75.0    84.0     30.0     56.0
# 2015   160.0    9.0   NaN   127.0       55.0    83.0     25.0     60.0
#
#       Markus  Marco   ...    Jean-Baptiste  Salih  Timéo  Arda  Karl-Heinz  \
# 1910     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1911     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1912     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1913     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1914     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1915     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1916     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1917     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1918     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# 1919     NaN    NaN   ...              NaN    NaN    NaN   NaN         NaN
# ...      ...    ...   ...              ...    ...    ...   ...         ...
# 2006    14.0  187.0   ...              NaN    5.0   18.0  50.0         NaN
# 2007    13.0  192.0   ...              NaN    NaN   32.0  41.0         NaN
# 2008    18.0  214.0   ...              3.0    3.0   34.0  54.0         NaN
# 2009    12.0  165.0   ...              NaN    NaN   46.0  48.0         NaN
# 2010    13.0  148.0   ...              NaN    5.0   45.0  25.0         NaN
# 2011    11.0  124.0   ...              5.0    5.0   34.0  17.0         NaN
# 2012    15.0  134.0   ...              NaN    3.0   31.0  16.0         NaN
# 2013     9.0  101.0   ...              NaN    7.0   48.0  19.0         NaN
# 2014    11.0  101.0   ...              NaN    4.0   52.0  17.0         NaN
# 2015     9.0  119.0   ...              NaN    4.0   51.0  15.0         NaN
#
#       Ensar  Renaud  Ezio  Joan  Magnus
# 1910    NaN     NaN   NaN   NaN     NaN
# 1911    NaN     NaN   NaN   NaN     NaN
# 1912    NaN     NaN   NaN   NaN     NaN
# 1913    NaN     NaN   NaN   NaN     NaN
# 1914    NaN     NaN   NaN   NaN     NaN
# 1915    NaN     NaN   NaN   NaN     NaN
# 1916    NaN     NaN   NaN   NaN     NaN
# 1917    NaN     NaN   NaN   NaN     NaN
# 1918    NaN     NaN   NaN   NaN     NaN
# 1919    NaN     NaN   NaN   NaN     NaN
# ...     ...     ...   ...   ...     ...
# 2006   29.0     NaN   NaN   9.0     4.0
# 2007   28.0     NaN   NaN  14.0     7.0
# 2008   19.0     NaN   NaN  14.0     6.0
# 2009   31.0     NaN   NaN  23.0    11.0
# 2010   32.0     NaN   4.0  13.0    11.0
# 2011   32.0     NaN   8.0  11.0     6.0
# 2012   27.0     NaN  10.0  18.0     7.0
# 2013   27.0     NaN   9.0  21.0     9.0
# 2014   24.0     NaN   7.0  25.0    16.0
# 2015   26.0     NaN   9.0  14.0    15.0
#
# [106 rows x 1001 columns]

# %%
girls
# Out:
#       Maria   Anna  Ruth  Ursula  Elisabeth  Sandra  Monika  Verena  Claudia  \
# 1910    NaN    3.0   NaN     NaN        NaN     NaN     NaN     NaN      NaN
# 1911    3.0    5.0   NaN     NaN        NaN     NaN     NaN     NaN      NaN
# 1912    4.0    6.0   NaN     NaN        NaN     NaN     NaN     NaN      NaN
# 1913    6.0   11.0   NaN     NaN        NaN     NaN     NaN     NaN      NaN
# 1914   13.0   17.0   NaN     NaN        8.0     NaN     NaN     NaN      NaN
# 1915   23.0   23.0   4.0     NaN        8.0     NaN     NaN     NaN      NaN
# 1916   33.0   26.0   NaN     NaN       16.0     NaN     NaN     NaN      NaN
# 1917   41.0   60.0   NaN     4.0       18.0     NaN     NaN    11.0      NaN
# 1918   66.0   72.0   8.0     3.0       31.0     NaN     NaN     8.0      NaN
# 1919   73.0   80.0  14.0    10.0       42.0     NaN     NaN    21.0      NaN
# ...     ...    ...   ...     ...        ...     ...     ...     ...      ...
# 2006  141.0  349.0   3.0     NaN       18.0    36.0     4.0     NaN     32.0
# 2007  139.0  282.0   6.0     NaN       22.0    31.0     9.0     3.0     23.0
# 2008  155.0  279.0   3.0     NaN       21.0    30.0     6.0     6.0     17.0
# 2009  114.0  290.0   7.0     NaN       23.0    17.0     6.0     NaN     11.0
# 2010  146.0  282.0   8.0     NaN       25.0    20.0     NaN     NaN     19.0
# 2011  134.0  282.0   5.0     3.0       28.0    20.0     5.0     4.0     20.0
# 2012  131.0  312.0   4.0     NaN       17.0     8.0     4.0     4.0     15.0
# 2013  123.0  277.0   NaN     NaN       25.0    13.0     8.0     NaN     20.0
# 2014  128.0  323.0   6.0     NaN       22.0    11.0     7.0     3.0     10.0
# 2015  132.0  302.0   NaN     NaN       36.0    17.0     6.0     6.0     13.0
#
#       Nicole  ...    Sevdije  Shania  Teodora  Bärbel  Cláudia  Marceline  \
# 1910     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1911     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1912     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1913     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1914     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1915     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1916     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1917     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1918     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# 1919     NaN  ...        NaN     NaN      NaN     NaN      NaN        NaN
# ...      ...  ...        ...     ...      ...     ...      ...        ...
# 2006    98.0  ...        NaN    24.0     14.0     NaN      NaN        NaN
# 2007    75.0  ...        NaN    23.0     14.0     NaN      NaN        NaN
# 2008    92.0  ...        NaN    18.0     20.0     NaN      3.0        NaN
# 2009    78.0  ...        NaN    20.0     18.0     NaN      NaN        NaN
# 2010    71.0  ...        NaN    14.0     17.0     NaN      NaN        NaN
# 2011    55.0  ...        NaN    20.0     15.0     NaN      NaN        NaN
# 2012    60.0  ...        NaN    28.0     14.0     NaN      NaN        NaN
# 2013    42.0  ...        NaN    21.0     20.0     NaN      NaN        NaN
# 2014    59.0  ...        NaN    22.0     18.0     NaN      NaN        NaN
# 2015    54.0  ...        NaN    11.0     23.0     NaN      NaN        NaN
#
#       Rosita  Hava  Kimberly  Mirta
# 1910     NaN   NaN       NaN    NaN
# 1911     NaN   NaN       NaN    NaN
# 1912     NaN   NaN       NaN    NaN
# 1913     NaN   NaN       NaN    NaN
# 1914     NaN   NaN       NaN    NaN
# 1915     NaN   NaN       NaN    NaN
# 1916     NaN   NaN       NaN    NaN
# 1917     NaN   NaN       NaN    NaN
# 1918     NaN   NaN       NaN    NaN
# 1919     NaN   NaN       NaN    NaN
# ...      ...   ...       ...    ...
# 2006     NaN   NaN      11.0    NaN
# 2007     NaN   3.0       9.0    NaN
# 2008     NaN   NaN      10.0    NaN
# 2009     NaN   NaN       7.0    NaN
# 2010     NaN   NaN       5.0    3.0
# 2011     NaN   5.0      16.0    NaN
# 2012     NaN   NaN       9.0    NaN
# 2013     NaN   NaN      12.0    NaN
# 2014     NaN   3.0       9.0    NaN
# 2015     NaN   8.0       9.0    NaN
#
# [106 rows x 1001 columns]

# %%
# write a function for the age of a name 
def age(ts):
    # get into probabilities
    p = ts.dropna()/ts.sum()
    # accumulate all the probabilities
    a = p.cumsum()
    # get the first index where at least 50% of the babies have been boren
    return a[a >= 0.5].index[0]

# %%
girls.apply(age).sort_values()
# Out:
# Berthe      1932
# Vreneli     1933
# Bertha      1933
# Hulda       1933
# Frieda      1934
# Marthe      1934
# Aloisia     1935
# Hermine     1936
# Bluette     1936
# Germaine    1936
#             ...
# Leana       2011
# Jara        2011
# Elin        2011
# Ava         2011
# Ela         2011
# Alea        2011
# Elea        2011
# Erina       2012
# Mila        2012
# Malea       2013
# dtype: int64

# %%
boys.apply(age).sort_values()
# Out:
# Hansruedi    1938
# Adolf        1940
# Willy        1942
# Otto         1942
# Gottlieb     1942
# Fernand      1943
# Gottfried    1943
# Gaston       1943
# Horst        1943
# August       1943
#              ...
# Timéo        2011
# Fynn         2011
# Liam         2011
# Lorik        2011
# Leart        2011
# Lian         2012
# Mael         2012
# Lean         2013
# Lio          2013
# Ajan         2014
# dtype: int64

# %%
boys["Adolf"].plot()

# %%
boys["Adolf"].truncate(before=1946).sum()
# Out:
# 845.0
